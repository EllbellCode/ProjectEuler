# %% [markdown]
# The following iterative sequence is defined for the set of positive integers:
#
# $n \rightarrow n/2$ ($n$ is even)
# $n \rightarrow 3n + 1$ ($n$ is odd)
#
# Using the rule above and starting with 13, we generate the following sequence:
#
# $$13 \rightarrow 40 \rightarrow 20 \rightarrow 10 \rightarrow 5 \rightarrow 16 \rightarrow 8 \rightarrow 4 \rightarrow 2 \rightarrow 1.$$
#
# It can be seen that this sequence (starting at 13 and finishing at 1) contains 10 terms. Although it has not been proved yet (Collatz Problem), it is thought that all starting numbers finish at 1.
#
# Which starting number, under one million, produces the longest chain?
#
# **NOTE:** Once the chain starts the terms are allowed to go above one million.

# %%
longest = 0
starting = 0
mem = {}

for i in range(1,1000000):

    chain = []
    currentNum = i
    chain.append(currentNum)

    while currentNum != 1:

        if currentNum in mem.keys():

            chain = chain + mem[currentNum]
            currentNum = 1

        else:

            if currentNum % 2 == 0:
                currentNum = currentNum/2
            else:
                currentNum = 3*currentNum + 1

            chain.append(currentNum)

    mem[currentNum] = chain

    if len(chain) >= longest:
        starting = i
        longest = len(chain)
        print(f"Starting Number {i} has chain of length {len(chain)}")

print(longest, starting)
# Out:
# Starting Number 1 has chain of length 1
# Starting Number 2 has chain of length 2
# Starting Number 3 has chain of length 8
# Starting Number 6 has chain of length 9
# Starting Number 7 has chain of length 17
# Starting Number 9 has chain of length 20
# Starting Number 18 has chain of length 21
# Starting Number 19 has chain of length 21
# Starting Number 25 has chain of length 24
# Starting Number 27 has chain of length 112
# Starting Number 54 has chain of length 113
# Starting Number 55 has chain of length 113
# Starting Number 73 has chain of length 116
# Starting Number 97 has chain of length 119
# Starting Number 129 has chain of length 122
# Starting Number 171 has chain of length 125
# Starting Number 231 has chain of length 128
# Starting Number 235 has chain of length 128
# Starting Number 313 has chain of length 131
# Starting Number 327 has chain of length 144
# Starting Number 649 has chain of length 145
# Starting Number 654 has chain of length 145
# ...

# %%
list = [1]

list = list + [2]

print(list)
# Out:
# [1, 2]
