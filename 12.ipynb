# %% [markdown]
# The sequence of triangle numbers is generated by adding the natural numbers. So the 7th triangle number would be $1 + 2 + 3 + 4 + 5 + 6 + 7 = 28$. The first ten terms would be:
#
# $$1, 3, 6, 10, 15, 21, 28, 36, 45, 55, \dots$$
#
# Let us list the factors of the first seven triangle numbers:
#
# **1:** 1
# **3:** 1, 3
# **6:** 1, 2, 3, 6
# **10:** 1, 2, 5, 10
# **15:** 1, 3, 5, 15
# **21:** 1, 3, 7, 21
# **28:** 1, 2, 4, 7, 14, 28
#
# We can see that 28 is the first triangle number to have over five divisors.
#
# What is the value of the first triangle number to have over five hundred divisors?

# %%
import math

triangleNums = [1]
divisorsFound = False
i = 2

while not divisorsFound:

    triangleNum = triangleNums[-1]

    ceiling = math.floor(triangleNum**0.5)
    #print(ceiling)

    divisors = []
    for j in range(1,ceiling+1):

        if triangleNum % j == 0:
            divisors.append(j)
            if triangleNum !=1:
                divisors.append(triangleNum/j)

    if round(triangleNum**0.5) == triangleNum**0.5 and triangleNum != 1:
        total = len(divisors) + 1
    else:
        total = len(divisors)
    
    print(f"Triangle Number {triangleNum} has {total} Divisors:")
    #print(divisors)
    if total > 500:
        divisorsFound = True

    else:
        triangleNums.append((triangleNum+i))
        i += 1

print(triangleNums[-1])
# Out:
# Triangle Number 1 has 1 Divisors:
# Triangle Number 3 has 2 Divisors:
# Triangle Number 6 has 4 Divisors:
# Triangle Number 10 has 4 Divisors:
# Triangle Number 15 has 4 Divisors:
# Triangle Number 21 has 4 Divisors:
# Triangle Number 28 has 6 Divisors:
# Triangle Number 36 has 11 Divisors:
# Triangle Number 45 has 6 Divisors:
# Triangle Number 55 has 4 Divisors:
# Triangle Number 66 has 8 Divisors:
# Triangle Number 78 has 8 Divisors:
# Triangle Number 91 has 4 Divisors:
# Triangle Number 105 has 8 Divisors:
# Triangle Number 120 has 16 Divisors:
# Triangle Number 136 has 8 Divisors:
# Triangle Number 153 has 6 Divisors:
# Triangle Number 171 has 6 Divisors:
# Triangle Number 190 has 8 Divisors:
# Triangle Number 210 has 16 Divisors:
# Triangle Number 231 has 8 Divisors:
# Triangle Number 253 has 4 Divisors:
# Triangle Number 276 has 12 Divisors:
# Triangle Number 300 has 18 Divisors:
# Triangle Number 325 has 6 Divisors:
# Triangle Number 351 has 8 Divisors:
# ...
